# %% [markdown]
# <a href="https://colab.research.google.com/github/gacerioni/redis-workshop-json-search-vs/blob/master/redis-workshop-vector-llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Workshop - Redis como VectorDB e RAG
# ## Vector Searches & Large Language Models
#
# ![Redis](https://redis.io/wp-content/uploads/2024/04/Logotype.svg?auto=webp&quality=85,75&width=120)
#
#
# Bem-vind[ao]s ao Workshop! Vamos ter uma experiência hands-on sobre alguns temas centrais do Redis, bem além do Caching.
#
#
# Para uma experiência premium, como a que eu quero que vocês tenham, recomendo MUITO utilizar o Redis Insight (App ou Web) pra apoiar na visualização dos dados.
#
# https://redis.com/redis-enterprise/redis-insight/
#
# ---
#
# Novamente, vamos direto ao ponto. Para pegar o fio da meada, passando pela introdução, veja este outro notebook [aqui](https://colab.research.google.com/github/gacerioni/redis-workshop-json-search-vs/blob/master/redis-workshop-vector-similarity-search.ipynb).
#
# ---
#
# ## Objetivos do Workshop
#
# Vamos tornar tangível um dos meus casos de uso favoritos com Redis e ChatGPT: RAG.
#
# Neste workshop, vamos usar o Redis como um cérebro extra, estilo cyberpunk, para o ChatGPT.
#
# Durante uma interação com o chat llm, vamos passar documentos do Redis como contexto privado e atualizado para o ChatGPT. Vamos ver juntos.
#
# ## Mas o que é RAG mesmo?
#
# **Retrieval-Augmented Generation** (RAG) é uma técnica poderosa no campo do Processamento de Linguagem Natural (NLP) que combina os pontos fortes dos modelos de linguagem pré-treinados com os benefícios dos sistemas de recuperação de informação ultra performáticos, como o nosso amigo Redis aqui.
#
# Em outras palavras, o RAG utiliza a busca semântica para encontrar informações relevantes e, em seguida, usa um modelo de linguagem para gerar respostas mais precisas e contextualmente relevantes para um usuário curioso, como nós, através de prompts.
#
# No contexto do Redis, isso significa usar o Redis como um banco de dados de vetores para armazenar e recuperar informações de forma eficiente. O Redis facilita a comparação de vetores para determinar similaridades, permitindo buscas rápidas e precisas.
#
# **Quando aplicado ao RAG, o Redis pode melhorar significativamente a precisão e relevância das respostas geradas por modelos de linguagem, reduzindo alucinações e fornecendo informações atualizadas. Sabe? Quando o ChatGPT fala com convicção algo completamente fora da caixinha? 😆**
#
#
#
#
# Espero que gostem! 🖖

# %% [markdown]
# # Setup Rápido
#
# ## Instalaçao das libs do Python e redis-cli

# %%
# Instale o Redis client e tambem o Hugging Face sentence transformers, pois vamos gerar os vetores aqui mesmo
# !pip install -q redis sentence_transformers

# Instale tbm algumas libs pra gente brincar com LLM
# este comando baixa umas paradas de 700MB+, ok? Leva dois minutinhos.
# !pip install -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt

# E instalar a CLI, via redis-tools, que inclui a famosa redis-cli
# !apt-get update
# !apt-get install -y redis-tools
# Out:
# Collecting aiohttp==3.9.3 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 1))
#   Downloading aiohttp-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal==1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 2)) (1.3.1)
# Collecting annotated-types==0.6.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 3))
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting anyio==4.3.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 4))
#   Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout==4.0.3 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 5)) (4.0.3)
# Requirement already satisfied: attrs==23.2.0 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 6)) (23.2.0)
# Requirement already satisfied: certifi==2024.2.2 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 7)) (2024.2.2)
# Requirement already satisfied: charset-normalizer==3.3.2 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 8)) (3.3.2)
# Collecting distro==1.9.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 9))
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting exceptiongroup==1.2.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 10))
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Collecting filelock==3.13.3 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 11))
#   Downloading filelock-3.13.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: frozenlist==1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 12)) (1.4.1)
# Collecting fsspec==2024.3.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 13))
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 4.9 MB/s eta 0:00:00
# Collecting h11==0.14.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 14))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# Collecting httpcore==1.0.4 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 15))
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 4.4 MB/s eta 0:00:00
# Collecting httpx==0.27.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 16))
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.4 MB/s eta 0:00:00
# Collecting huggingface-hub==0.22.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 17))
#   Downloading huggingface_hub-0.22.1-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.6/388.6 kB 3.5 MB/s eta 0:00:00
# Collecting idna==3.6 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 18))
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.0 MB/s eta 0:00:00
# Collecting Jinja2==3.1.3 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 19))
#   Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 5.1 MB/s eta 0:00:00
# Collecting joblib==1.3.2 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 20))
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe==2.1.5 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 21)) (2.1.5)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 22)) (1.3.0)
# Requirement already satisfied: multidict==6.0.5 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 23)) (6.0.5)
# Collecting networkx==3.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 24))
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.1 MB/s eta 0:00:00
# Collecting numpy==1.24.4 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 25))
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 6.0 MB/s eta 0:00:00
# Collecting openai==0.28.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 26))
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging==24.0 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 27)) (24.0)
# Collecting pillow==10.2.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 28))
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 6.4 MB/s eta 0:00:00
# Collecting pydantic==2.6.4 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 29))
#   Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 6.8 MB/s eta 0:00:00
# Collecting pydantic_core==2.16.3 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 30))
#   Downloading pydantic_core-2.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.7 MB/s eta 0:00:00
# Collecting python-dotenv==1.0.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 31))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 32)) (6.0.1)
# Collecting redis==5.0.3 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 33))
#   Downloading redis-5.0.3-py3-none-any.whl (251 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.8/251.8 kB 7.4 MB/s eta 0:00:00
# Collecting regex==2023.12.25 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 34))
#   Downloading regex-2023.12.25-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.0/774.0 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 35)) (2.31.0)
# Collecting safetensors==0.4.2 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 36))
#   Downloading safetensors-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.7 MB/s eta 0:00:00
# Collecting scikit-learn==1.3.2 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 37))
#   Downloading scikit_learn-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 3.4 MB/s eta 0:00:00
# Collecting scipy==1.10.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 38))
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 4.9 MB/s eta 0:00:00
# Collecting sentence-transformers==2.6.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 39))
#   Downloading sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 40)) (1.3.1)
# Requirement already satisfied: sympy==1.12 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 41)) (1.12)
# Collecting threadpoolctl==3.4.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 42))
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Collecting tiktoken==0.6.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 43))
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.8 MB/s eta 0:00:00
# Collecting tokenizers==0.15.2 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 44))
#   Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 3.3 MB/s eta 0:00:00
# Collecting torch==2.2.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45))
#   Downloading torch-2.2.1-cp310-cp310-manylinux1_x86_64.whl (755.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.6 MB/s eta 0:00:00
# Collecting tqdm==4.66.2 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 46))
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 12.5 MB/s eta 0:00:00
# Collecting transformers==4.39.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 47))
#   Downloading transformers-4.39.1-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 18.0 MB/s eta 0:00:00
# Collecting typing_extensions==4.10.0 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 48))
#   Downloading typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Collecting urllib3==2.2.1 (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 49))
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: yarl==1.9.4 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 50)) (1.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (12.1.0.106)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (12.1.105)
# Collecting triton==2.2.0 (from torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45))
#   Downloading triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->-r https://raw.githubusercontent.com/gacerioni/redis-workshop-json-search-vs/master/deps/llm-movies/requirements.txt (line 45)) (12.5.40)
# Installing collected packages: urllib3, typing_extensions, tqdm, threadpoolctl, safetensors, regex, redis, python-dotenv, pillow, nvidia-nccl-cu12, numpy, networkx, joblib, Jinja2, idna, h11, fsspec, filelock, exceptiongroup, distro, annotated-types, triton, scipy, pydantic_core, httpcore, anyio, torch, tiktoken, scikit-learn, pydantic, huggingface-hub, httpx, aiohttp, tokenizers, openai, transformers, sentence-transformers
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.3
#     Uninstalling safetensors-0.4.3:
#       Successfully uninstalled safetensors-0.4.3
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.5.15
#     Uninstalling regex-2024.5.15:
#       Successfully uninstalled regex-2024.5.15
#   Attempting uninstall: redis
#     Found existing installation: redis 5.0.4
#     Uninstalling redis-5.0.4:
#       Successfully uninstalled redis-5.0.4
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.20.5
#     Uninstalling nvidia-nccl-cu12-2.20.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.20.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.3
#     Uninstalling networkx-3.3:
#       Successfully uninstalled networkx-3.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.14.0
#     Uninstalling filelock-3.14.0:
#       Successfully uninstalled filelock-3.14.0
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.1
#     Uninstalling exceptiongroup-1.2.1:
#       Successfully uninstalled exceptiongroup-1.2.1
#   Attempting uninstall: distro
#     Found existing installation: distro 1.7.0
#     Uninstalling distro-1.7.0:
#       Successfully uninstalled distro-1.7.0
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.0
#     Uninstalling triton-2.3.0:
#       Successfully uninstalled triton-2.3.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: pydantic_core
#     Found existing installation: pydantic_core 2.18.2
#     Uninstalling pydantic_core-2.18.2:
#       Successfully uninstalled pydantic_core-2.18.2
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.7.1
#     Uninstalling pydantic-2.7.1:
#       Successfully uninstalled pydantic-2.7.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.23.1
#     Uninstalling huggingface-hub-0.23.1:
#       Successfully uninstalled huggingface-hub-0.23.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.9.5
#     Uninstalling aiohttp-3.9.5:
#       Successfully uninstalled aiohttp-3.9.5
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.41.1
#     Uninstalling transformers-4.41.1:
#       Successfully uninstalled transformers-4.41.1
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.0.0
#     Uninstalling sentence-transformers-3.0.0:
#       Successfully uninstalled sentence-transformers-3.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.3.1 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.3.0 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 2.2.1 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.2.1 which is incompatible.
# torchvision 0.18.0+cu121 requires torch==2.3.0, but you have torch 2.2.1 which is incompatible.
# Successfully installed Jinja2-3.1.3 aiohttp-3.9.3 annotated-types-0.6.0 anyio-4.3.0 distro-1.9.0 exceptiongroup-1.2.0 filelock-3.13.3 fsspec-2024.3.1 h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 huggingface-hub-0.22.1 idna-3.6 joblib-1.3.2 networkx-3.1 numpy-1.24.4 nvidia-nccl-cu12-2.19.3 openai-0.28.0 pillow-10.2.0 pydantic-2.6.4 pydantic_core-2.16.3 python-dotenv-1.0.1 redis-5.0.3 regex-2023.12.25 safetensors-0.4.2 scikit-learn-1.3.2 scipy-1.10.1 sentence-transformers-2.6.1 threadpoolctl-3.4.0 tiktoken-0.6.0 tokenizers-0.15.2 torch-2.2.1 tqdm-4.66.2 transformers-4.39.1 triton-2.2.0 typing_extensions-4.10.0 urllib3-2.2.1
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://packages.redis.io/deb jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ^C

# %% [markdown]
# ## Deployment do Redis Stack - Um passo importante para esta demo em específico
#
# Pessoal, esse Workshop de VectorSearch vai passar de 30MB.
#
# ---
#
# **Ou seja: pra gente poder fazer esse e os futuros de Vector com LLM, vamos rodar o `redis-stack` aqui, locamente, neste notebook mesmo.**
#
# ---
#
# Para isso, basta executar:

# %%
# %%sh
# curl -fsSL https://packages.redis.io/gpg | sudo gpg --dearmor -o /usr/share/keyrings/redis-archive-keyring.gpg
# echo "deb [signed-by=/usr/share/keyrings/redis-archive-keyring.gpg] https://packages.redis.io/deb $(lsb_release -cs) main" | sudo tee /etc/apt/sources.list.d/redis.list
# sudo apt-get update  > /dev/null 2>&1
# sudo apt-get install redis-stack-server  > /dev/null 2>&1
# redis-stack-server --daemonize yes
# Out:
# deb [signed-by=/usr/share/keyrings/redis-archive-keyring.gpg] https://packages.redis.io/deb jammy main
# Starting redis-stack-server, database path /var/lib/redis-stack
# gpg: cannot open '/dev/tty': No such device or address
# curl: (23) Failed writing body

# %% [markdown]
# ### Conectando com o Redis server

# %%
import os

# Coloque aqui os dados do seu DB do Redis Cloud
REDIS_HOST="localhost"
REDIS_PORT=6379
REDIS_PASSWORD=""

# Caso o SSL esteja ativo pro endpoint, adicione --tls
# Recomendo não misturar lé com cré aqui, visto que não vamos ter nenhuma informação sensível passando pelo fio.
if REDIS_PASSWORD!="":
  os.environ["REDIS_CONN"]=f"-h {REDIS_HOST} -p {REDIS_PORT} -a {REDIS_PASSWORD} --no-auth-warning"
else:
  os.environ["REDIS_CONN"]=f"-h {REDIS_HOST} -p {REDIS_PORT}"

# Caso o SSL esteja ativo pro endpoint, use rediss:// como o URL prefix
REDIS_URL = f"redis://:{REDIS_PASSWORD}@{REDIS_HOST}:{REDIS_PORT}"
INDEX_NAME = f"qna:idx"

# Teste a Redis connection
# !redis-cli $REDIS_CONN PING
# Out:
# PONG

# %%
# Testando via Python (redis-py)
import redis
redis = redis.Redis(
  host=REDIS_HOST,
  port=REDIS_PORT,
  password=REDIS_PASSWORD)
redis.ping()
# Out:
# True

# %% [markdown]
# ## Importando e preparando as libs que iremos usar
#
# Este primeiro bloco vai garantir que todas as dependências estejam prontas pra gente brincar com o ChatGPT usando o Redis como um cérebro extra e atualizado.
#
# O bloco de variáveis ali é basicamente eu explicando algumas preferências minhas pro Vector Search, como quantas dimensões meus vetores possuem. 384, neste caso.

# %%
import redis
import csv
import os
import numpy as np
from sentence_transformers import *
from redis.commands.search.query import Query
from redis.commands.search.field import TextField, TagField, VectorField
from redis.commands.search.indexDefinition import IndexDefinition, IndexType
import openai
import tiktoken


redis = redis.Redis(
  host=REDIS_HOST,
  port=REDIS_PORT,
  password=REDIS_PASSWORD,
  decode_responses=True)

# Preferencias acerca do nosso Vector Search e como o Redis deve indexar os embeddings
VSS_INDEX_TYPE = "HNSW"
VSS_DATA_TYPE = "FLOAT32"
VSS_DISTANCE = "COSINE"
VSS_DIMENSION = 384
VSS_MINIMUM_SCORE = 2

#MAX_MOVIES = 50000


redis.ping()
# Out:
# True

# %% [markdown]
# # Iniciando os trabalhos
#
# ## Passo 1 - Carregando os filmes no Redis
#
# Primeiro, vamos baixar o CSV do nosso GitHub, contendo um monte de filmes.\
# Eu fiz um dump da base do **[IMDB](https://www.imdb.com/)**, caso estejam curiosos.

# %%
# Baixando
# !wget https://raw.githubusercontent.com/gacerioni/gabs-chatbot-llm-gpt-redis-vector-rag-demo/main/data/movies/imdb_movies.csv
# Out:
# --2024-05-28 19:57:21--  https://raw.githubusercontent.com/gacerioni/gabs-chatbot-llm-gpt-redis-vector-rag-demo/main/data/movies/imdb_movies.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6713035 (6.4M) [text/plain]
# Saving to: ‘imdb_movies.csv’
#
# imdb_movies.csv     100%[===================>]   6.40M  --.-KB/s    in 0.09s
#
# 2024-05-28 19:57:21 (74.1 MB/s) - ‘imdb_movies.csv’ saved [6713035/6713035]

# %%
def load():
    with open("imdb_movies.csv", encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
        cnt = 0
        for row in csvReader:
            redis.json().set(f'moviebot:movie:{cnt}', '$', row)
            cnt = cnt + 1
            if (cnt > MAX_MOVIES):
                break
        print("Data was loaded into Redis!")

# Flush no DB, pra gente começar do 0
redis.flushdb()

# Carregar os dados no Redis
load()


# Contar as chaves no Redis, só pra ver se tudo foi carregado
key_count = redis.dbsize()
print(f"Total de chaves no Redis: {key_count}")
# Out:
# Data was loaded into Redis!
# Total de chaves no Redis: 10178

# %% [markdown]
# E ver alguns dados, só pra ter certeza que subiram para o Redis.
#
# Notem que a gente não criou os vetores ainda, belê?

# %%
redis.json().get("moviebot:movie:1")
# Out:
# {'names': 'Avatar: The Way of Water',
#  'date_x': '12/15/2022 ',
#  'score': '78.0',
#  'genre': 'Science Fiction,\xa0Adventure,\xa0Action',
#  'overview': 'Set more than a decade after the events of the first film, learn the story of the Sully family (Jake, Neytiri, and their kids), the trouble that follows them, the lengths they go to keep each other safe, the battles they fight to stay alive, and the tragedies they endure.',
#  'crew': "Sam Worthington, Jake Sully, Zoe Saldaña, Neytiri, Sigourney Weaver, Kiri / Dr. Grace Augustine, Stephen Lang, Colonel Miles Quaritch, Kate Winslet, Ronal, Cliff Curtis, Tonowari, Joel David Moore, Norm Spellman, CCH Pounder, Mo'at, Edie Falco, General Frances Ardmore",
#  'orig_title': 'Avatar: The Way of Water',
#  'status': ' Released',
#  'orig_lang': ' English',
#  'budget_x': '460000000.0',
#  'revenue': '2316794914.0',
#  'country': 'AU'}

# %% [markdown]
# ## Passo 2 - Embedding - Hora de gerar vetores!
#
# Finalmente, vamos ver nosso banco de vetores tomando forma.
#
# Para isso, pegaremos alguns campos de informações não estruturadas de cada filme. Vamos concatenar dados interessantes como título, gênero, equipe, pontuação e sinopse.
#
# Com essa string concatenada, geraremos vetores que representam cada filme de maneira embutida. Esses vetores serão armazenados no Redis, permitindo buscas e análises semânticas avançadas sobre os filmes.

# %%
# esse comando pode levar 1-2 minutos, ok?
def create_embeddings():
    model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
    for key in redis.scan_iter(match='moviebot:movie:*'):
        print(f"creating the embedding for {key}")
        result = redis.json().get(key, "$.names", "$.overview", "$.crew", "$.score", "$.genre")
        movie = f"movie title is: {result['$.names'][0]}\n"
        movie += f"movie genre is: {result['$.genre'][0]}\n"
        movie += f"movie crew is: {result['$.crew'][0]}\n"
        movie += f"movie score is: {result['$.score'][0]}\n"
        movie += f"movie overview is: {result['$.overview'][0]}\n"
        redis.json().set(key, "$.overview_embedding", model.encode(movie).astype(np.float32).tolist())

create_embeddings()
# Out:
# Streaming output truncated to the last 5000 lines.
# creating the embedding for moviebot:movie:8787
# creating the embedding for moviebot:movie:7950
# creating the embedding for moviebot:movie:1436
# creating the embedding for moviebot:movie:10089
# creating the embedding for moviebot:movie:3310
# creating the embedding for moviebot:movie:7002
# creating the embedding for moviebot:movie:8676
# creating the embedding for moviebot:movie:3662
# creating the embedding for moviebot:movie:6678
# creating the embedding for moviebot:movie:4650
# creating the embedding for moviebot:movie:9825
# creating the embedding for moviebot:movie:4265
# creating the embedding for moviebot:movie:7867
# creating the embedding for moviebot:movie:8306
# creating the embedding for moviebot:movie:434
# creating the embedding for moviebot:movie:9279
# creating the embedding for moviebot:movie:8243
# creating the embedding for moviebot:movie:5053
# creating the embedding for moviebot:movie:10120
# creating the embedding for moviebot:movie:3980
# creating the embedding for moviebot:movie:1026
# creating the embedding for moviebot:movie:5765
# creating the embedding for moviebot:movie:6563
# creating the embedding for moviebot:movie:9374
# creating the embedding for moviebot:movie:9723
# creating the embedding for moviebot:movie:5201
# creating the embedding for moviebot:movie:777
# creating the embedding for moviebot:movie:1384
# creating the embedding for moviebot:movie:146
# creating the embedding for moviebot:movie:1310
# creating the embedding for moviebot:movie:8805
# creating the embedding for moviebot:movie:1810
# creating the embedding for moviebot:movie:4612
# creating the embedding for moviebot:movie:983
# creating the embedding for moviebot:movie:3884
# creating the embedding for moviebot:movie:839
# creating the embedding for moviebot:movie:6212
# creating the embedding for moviebot:movie:7076
# creating the embedding for moviebot:movie:7857
# creating the embedding for moviebot:movie:6055
# creating the embedding for moviebot:movie:0
# creating the embedding for moviebot:movie:6620
# creating the embedding for moviebot:movie:5844
# creating the embedding for moviebot:movie:3359
# creating the embedding for moviebot:movie:9545
# creating the embedding for moviebot:movie:1838
# creating the embedding for moviebot:movie:2324
# creating the embedding for moviebot:movie:6790
# creating the embedding for moviebot:movie:4313
# creating the embedding for moviebot:movie:4935
# creating the embedding for moviebot:movie:5174
# creating the embedding for moviebot:movie:1750
# creating the embedding for moviebot:movie:2745
# creating the embedding for moviebot:movie:1301
# creating the embedding for moviebot:movie:9941
# creating the embedding for moviebot:movie:9231
# creating the embedding for moviebot:movie:3336
# creating the embedding for moviebot:movie:6316
# creating the embedding for moviebot:movie:4983
# creating the embedding for moviebot:movie:2945
# creating the embedding for moviebot:movie:6551
# creating the embedding for moviebot:movie:7919
# creating the embedding for moviebot:movie:7650
# creating the embedding for moviebot:movie:8735
# creating the embedding for moviebot:movie:2740
# creating the embedding for moviebot:movie:405
# creating the embedding for moviebot:movie:464
# creating the embedding for moviebot:movie:7075
# creating the embedding for moviebot:movie:8919
# creating the embedding for moviebot:movie:1417
# creating the embedding for moviebot:movie:1526
# creating the embedding for moviebot:movie:2631
# creating the embedding for moviebot:movie:738
# creating the embedding for moviebot:movie:6549
# creating the embedding for moviebot:movie:8242
# creating the embedding for moviebot:movie:6059
# creating the embedding for moviebot:movie:6110
# creating the embedding for moviebot:movie:8136
# creating the embedding for moviebot:movie:9179
# creating the embedding for moviebot:movie:7149
# creating the embedding for moviebot:movie:8199
# creating the embedding for moviebot:movie:3545
# creating the embedding for moviebot:movie:8126
# creating the embedding for moviebot:movie:6286
# creating the embedding for moviebot:movie:7209
# creating the embedding for moviebot:movie:9647
# creating the embedding for moviebot:movie:6124
# creating the embedding for moviebot:movie:4014
# creating the embedding for moviebot:movie:7169
# creating the embedding for moviebot:movie:9038
# creating the embedding for moviebot:movie:4112
# creating the embedding for moviebot:movie:3343
# creating the embedding for moviebot:movie:1432
# creating the embedding for moviebot:movie:5057
# creating the embedding for moviebot:movie:7033
# creating the embedding for moviebot:movie:2654
# creating the embedding for moviebot:movie:5705
# creating the embedding for moviebot:movie:720
# creating the embedding for moviebot:movie:10085
# creating the embedding for moviebot:movie:5480
# creating the embedding for moviebot:movie:6543
# creating the embedding for moviebot:movie:3155
# creating the embedding for moviebot:movie:7745
# creating the embedding for moviebot:movie:7616
# creating the embedding for moviebot:movie:2782
# creating the embedding for moviebot:movie:5259
# creating the embedding for moviebot:movie:9116
# creating the embedding for moviebot:movie:928
# creating the embedding for moviebot:movie:6324
# creating the embedding for moviebot:movie:4412
# creating the embedding for moviebot:movie:7248
# creating the embedding for moviebot:movie:7781
# creating the embedding for moviebot:movie:8839
# creating the embedding for moviebot:movie:3952
# creating the embedding for moviebot:movie:3840
# creating the embedding for moviebot:movie:9050
# creating the embedding for moviebot:movie:9650
# creating the embedding for moviebot:movie:6997
# creating the embedding for moviebot:movie:930
# creating the embedding for moviebot:movie:9839
# creating the embedding for moviebot:movie:627
# creating the embedding for moviebot:movie:2965
# creating the embedding for moviebot:movie:5432
# creating the embedding for moviebot:movie:2547
# creating the embedding for moviebot:movie:8390
# creating the embedding for moviebot:movie:1982
# creating the embedding for moviebot:movie:1881
# creating the embedding for moviebot:movie:1934
# creating the embedding for moviebot:movie:139
# creating the embedding for moviebot:movie:6404
# creating the embedding for moviebot:movie:6679
# creating the embedding for moviebot:movie:9930
# creating the embedding for moviebot:movie:3585
# creating the embedding for moviebot:movie:1252
# creating the embedding for moviebot:movie:1044
# creating the embedding for moviebot:movie:7390
# creating the embedding for moviebot:movie:9726
# creating the embedding for moviebot:movie:4488
# creating the embedding for moviebot:movie:489
# creating the embedding for moviebot:movie:6123
# creating the embedding for moviebot:movie:2723
# creating the embedding for moviebot:movie:5198
# creating the embedding for moviebot:movie:5756
# creating the embedding for moviebot:movie:297
# creating the embedding for moviebot:movie:282
# creating the embedding for moviebot:movie:7280
# creating the embedding for moviebot:movie:9133
# creating the embedding for moviebot:movie:4847
# creating the embedding for moviebot:movie:6473
# creating the embedding for moviebot:movie:9330
# creating the embedding for moviebot:movie:8090
# creating the embedding for moviebot:movie:744
# creating the embedding for moviebot:movie:5702
# creating the embedding for moviebot:movie:834
# creating the embedding for moviebot:movie:4950
# creating the embedding for moviebot:movie:3684
# creating the embedding for moviebot:movie:7775
# creating the embedding for moviebot:movie:5446
# creating the embedding for moviebot:movie:1842
# creating the embedding for moviebot:movie:6157
# creating the embedding for moviebot:movie:8360
# creating the embedding for moviebot:movie:9519
# creating the embedding for moviebot:movie:9974
# creating the embedding for moviebot:movie:5819
# creating the embedding for moviebot:movie:6544
# creating the embedding for moviebot:movie:6117
# creating the embedding for moviebot:movie:4881
# creating the embedding for moviebot:movie:2548
# creating the embedding for moviebot:movie:9997
# creating the embedding for moviebot:movie:5001
# creating the embedding for moviebot:movie:1054
# creating the embedding for moviebot:movie:8557
# creating the embedding for moviebot:movie:5925
# creating the embedding for moviebot:movie:2359
# creating the embedding for moviebot:movie:4450
# creating the embedding for moviebot:movie:7356
# creating the embedding for moviebot:movie:3918
# creating the embedding for moviebot:movie:7854
# creating the embedding for moviebot:movie:9010
# creating the embedding for moviebot:movie:3490
# creating the embedding for moviebot:movie:7118
# creating the embedding for moviebot:movie:7619
# creating the embedding for moviebot:movie:10177
# creating the embedding for moviebot:movie:1022
# creating the embedding for moviebot:movie:5178
# creating the embedding for moviebot:movie:6100
# creating the embedding for moviebot:movie:1312
# creating the embedding for moviebot:movie:7287
# creating the embedding for moviebot:movie:9459
# creating the embedding for moviebot:movie:1771
# creating the embedding for moviebot:movie:9790
# creating the embedding for moviebot:movie:2107
# creating the embedding for moviebot:movie:8141
# creating the embedding for moviebot:movie:3605
# creating the embedding for moviebot:movie:4343
# creating the embedding for moviebot:movie:1469
# creating the embedding for moviebot:movie:9130
# creating the embedding for moviebot:movie:902
# creating the embedding for moviebot:movie:6147
# creating the embedding for moviebot:movie:754
# creating the embedding for moviebot:movie:782
# creating the embedding for moviebot:movie:663
# creating the embedding for moviebot:movie:6290
# creating the embedding for moviebot:movie:2319
# creating the embedding for moviebot:movie:2151
# creating the embedding for moviebot:movie:3678
# creating the embedding for moviebot:movie:5603
# creating the embedding for moviebot:movie:6355
# creating the embedding for moviebot:movie:5821
# creating the embedding for moviebot:movie:9628
# creating the embedding for moviebot:movie:2266
# creating the embedding for moviebot:movie:1878
# creating the embedding for moviebot:movie:7936
# creating the embedding for moviebot:movie:7740
# creating the embedding for moviebot:movie:9619
# creating the embedding for moviebot:movie:9058
# creating the embedding for moviebot:movie:7536
# creating the embedding for moviebot:movie:8069
# creating the embedding for moviebot:movie:1633
# creating the embedding for moviebot:movie:3188
# creating the embedding for moviebot:movie:497
# creating the embedding for moviebot:movie:1799
# creating the embedding for moviebot:movie:8986
# creating the embedding for moviebot:movie:2943
# creating the embedding for moviebot:movie:3693
# creating the embedding for moviebot:movie:7087
# creating the embedding for moviebot:movie:2776
# creating the embedding for moviebot:movie:1127
# creating the embedding for moviebot:movie:7872
# creating the embedding for moviebot:movie:8362
# creating the embedding for moviebot:movie:3117
# creating the embedding for moviebot:movie:5557
# creating the embedding for moviebot:movie:9053
# creating the embedding for moviebot:movie:236
# creating the embedding for moviebot:movie:4896
# creating the embedding for moviebot:movie:7113
# creating the embedding for moviebot:movie:4181
# creating the embedding for moviebot:movie:9037
# creating the embedding for moviebot:movie:4600
# creating the embedding for moviebot:movie:4720
# creating the embedding for moviebot:movie:3583
# creating the embedding for moviebot:movie:4636
# creating the embedding for moviebot:movie:1858
# creating the embedding for moviebot:movie:1996
# creating the embedding for moviebot:movie:8149
# creating the embedding for moviebot:movie:3342
# creating the embedding for moviebot:movie:4519
# creating the embedding for moviebot:movie:1700
# creating the embedding for moviebot:movie:794
# creating the embedding for moviebot:movie:272
# creating the embedding for moviebot:movie:9983
# creating the embedding for moviebot:movie:9688
# creating the embedding for moviebot:movie:4708
# creating the embedding for moviebot:movie:7719
# creating the embedding for moviebot:movie:9181
# creating the embedding for moviebot:movie:3941
# creating the embedding for moviebot:movie:9163
# creating the embedding for moviebot:movie:9488
# creating the embedding for moviebot:movie:8863
# creating the embedding for moviebot:movie:1049
# creating the embedding for moviebot:movie:5888
# creating the embedding for moviebot:movie:874
# creating the embedding for moviebot:movie:8662
# creating the embedding for moviebot:movie:207
# creating the embedding for moviebot:movie:8652
# creating the embedding for moviebot:movie:3773
# creating the embedding for moviebot:movie:564
# creating the embedding for moviebot:movie:7606
# creating the embedding for moviebot:movie:3987
# creating the embedding for moviebot:movie:6669
# creating the embedding for moviebot:movie:3790
# creating the embedding for moviebot:movie:5961
# creating the embedding for moviebot:movie:7309
# creating the embedding for moviebot:movie:6701
# creating the embedding for moviebot:movie:6504
# creating the embedding for moviebot:movie:6030
# creating the embedding for moviebot:movie:1596
# creating the embedding for moviebot:movie:9123
# creating the embedding for moviebot:movie:4
# creating the embedding for moviebot:movie:5700
# creating the embedding for moviebot:movie:8584
# creating the embedding for moviebot:movie:5824
# creating the embedding for moviebot:movie:7030
# creating the embedding for moviebot:movie:8674
# creating the embedding for moviebot:movie:2780
# creating the embedding for moviebot:movie:4387
# creating the embedding for moviebot:movie:4934
# creating the embedding for moviebot:movie:7558
# creating the embedding for moviebot:movie:6897
# creating the embedding for moviebot:movie:8658
# creating the embedding for moviebot:movie:3857
# creating the embedding for moviebot:movie:8579
# creating the embedding for moviebot:movie:3645
# creating the embedding for moviebot:movie:7282
# creating the embedding for moviebot:movie:7291
# creating the embedding for moviebot:movie:3982
# creating the embedding for moviebot:movie:1346
# creating the embedding for moviebot:movie:2308
# creating the embedding for moviebot:movie:575
# creating the embedding for moviebot:movie:3239
# creating the embedding for moviebot:movie:7305
# creating the embedding for moviebot:movie:1736
# creating the embedding for moviebot:movie:8434
# creating the embedding for moviebot:movie:9028
# creating the embedding for moviebot:movie:5681
# creating the embedding for moviebot:movie:98
# creating the embedding for moviebot:movie:5515
# creating the embedding for moviebot:movie:9996
# creating the embedding for moviebot:movie:7759
# creating the embedding for moviebot:movie:8965
# creating the embedding for moviebot:movie:4019
# creating the embedding for moviebot:movie:8971
# creating the embedding for moviebot:movie:8912
# creating the embedding for moviebot:movie:6769
# creating the embedding for moviebot:movie:5478
# creating the embedding for moviebot:movie:5228
# creating the embedding for moviebot:movie:1145
# creating the embedding for moviebot:movie:1933
# creating the embedding for moviebot:movie:665
# creating the embedding for moviebot:movie:1453
# creating the embedding for moviebot:movie:4652
# creating the embedding for moviebot:movie:6860
# creating the embedding for moviebot:movie:2946
# creating the embedding for moviebot:movie:8883
# creating the embedding for moviebot:movie:7230
# creating the embedding for moviebot:movie:3339
# creating the embedding for moviebot:movie:718
# creating the embedding for moviebot:movie:2118
# creating the embedding for moviebot:movie:3909
# creating the embedding for moviebot:movie:8374
# creating the embedding for moviebot:movie:8789
# creating the embedding for moviebot:movie:2348
# creating the embedding for moviebot:movie:2339
# creating the embedding for moviebot:movie:829
# creating the embedding for moviebot:movie:5572
# creating the embedding for moviebot:movie:5974
# creating the embedding for moviebot:movie:427
# creating the embedding for moviebot:movie:6322
# creating the embedding for moviebot:movie:10165
# creating the embedding for moviebot:movie:6284
# creating the embedding for moviebot:movie:8474
# creating the embedding for moviebot:movie:11
# creating the embedding for moviebot:movie:4594
# creating the embedding for moviebot:movie:8180
# creating the embedding for moviebot:movie:9781
# creating the embedding for moviebot:movie:1042
# creating the embedding for moviebot:movie:9999
# creating the embedding for moviebot:movie:161
# creating the embedding for moviebot:movie:4301
# creating the embedding for moviebot:movie:10025
# creating the embedding for moviebot:movie:2390
# creating the embedding for moviebot:movie:9346
# creating the embedding for moviebot:movie:4479
# creating the embedding for moviebot:movie:1136
# creating the embedding for moviebot:movie:3402
# creating the embedding for moviebot:movie:1513
# creating the embedding for moviebot:movie:5958
# creating the embedding for moviebot:movie:1218
# creating the embedding for moviebot:movie:869
# creating the embedding for moviebot:movie:1915
# creating the embedding for moviebot:movie:3275
# creating the embedding for moviebot:movie:3466
# creating the embedding for moviebot:movie:970
# creating the embedding for moviebot:movie:4906
# creating the embedding for moviebot:movie:2841
# creating the embedding for moviebot:movie:9421
# creating the embedding for moviebot:movie:4765
# creating the embedding for moviebot:movie:224
# creating the embedding for moviebot:movie:6080
# creating the embedding for moviebot:movie:5544
# creating the embedding for moviebot:movie:3471
# creating the embedding for moviebot:movie:2626
# creating the embedding for moviebot:movie:2614
# creating the embedding for moviebot:movie:3616
# creating the embedding for moviebot:movie:4517
# creating the embedding for moviebot:movie:10070
# creating the embedding for moviebot:movie:9149
# creating the embedding for moviebot:movie:4317
# creating the embedding for moviebot:movie:8163
# creating the embedding for moviebot:movie:6276
# creating the embedding for moviebot:movie:9627
# creating the embedding for moviebot:movie:4296
# creating the embedding for moviebot:movie:4527
# creating the embedding for moviebot:movie:2532
# creating the embedding for moviebot:movie:7705
# creating the embedding for moviebot:movie:5554
# creating the embedding for moviebot:movie:6431
# creating the embedding for moviebot:movie:2970
# creating the embedding for moviebot:movie:2941
# creating the embedding for moviebot:movie:8497
# creating the embedding for moviebot:movie:4055
# creating the embedding for moviebot:movie:421
# creating the embedding for moviebot:movie:2633
# creating the embedding for moviebot:movie:8915
# creating the embedding for moviebot:movie:331
# creating the embedding for moviebot:movie:8607
# creating the embedding for moviebot:movie:3932
# creating the embedding for moviebot:movie:8592
# creating the embedding for moviebot:movie:291
# creating the embedding for moviebot:movie:640
# creating the embedding for moviebot:movie:9048
# creating the embedding for moviebot:movie:8992
# creating the embedding for moviebot:movie:6333
# creating the embedding for moviebot:movie:876
# creating the embedding for moviebot:movie:7241
# creating the embedding for moviebot:movie:5084
# creating the embedding for moviebot:movie:1122
# creating the embedding for moviebot:movie:4080
# creating the embedding for moviebot:movie:4534
# creating the embedding for moviebot:movie:6941
# creating the embedding for moviebot:movie:9527
# creating the embedding for moviebot:movie:2240
# creating the embedding for moviebot:movie:486
# creating the embedding for moviebot:movie:7728
# creating the embedding for moviebot:movie:5023
# creating the embedding for moviebot:movie:7742
# creating the embedding for moviebot:movie:6558
# creating the embedding for moviebot:movie:1097
# creating the embedding for moviebot:movie:8724
# creating the embedding for moviebot:movie:9762
# creating the embedding for moviebot:movie:138
# creating the embedding for moviebot:movie:2195
# creating the embedding for moviebot:movie:2052
# creating the embedding for moviebot:movie:2046
# creating the embedding for moviebot:movie:3627
# creating the embedding for moviebot:movie:5169
# creating the embedding for moviebot:movie:1916
# creating the embedding for moviebot:movie:7474
# creating the embedding for moviebot:movie:8115
# creating the embedding for moviebot:movie:8113
# creating the embedding for moviebot:movie:10033
# creating the embedding for moviebot:movie:1648
# creating the embedding for moviebot:movie:7412
# creating the embedding for moviebot:movie:4201
# creating the embedding for moviebot:movie:7491
# creating the embedding for moviebot:movie:5768
# creating the embedding for moviebot:movie:7816
# creating the embedding for moviebot:movie:9986
# creating the embedding for moviebot:movie:9736
# creating the embedding for moviebot:movie:9281
# creating the embedding for moviebot:movie:3767
# creating the embedding for moviebot:movie:6707
# creating the embedding for moviebot:movie:899
# creating the embedding for moviebot:movie:2122
# creating the embedding for moviebot:movie:8878
# creating the embedding for moviebot:movie:6295
# creating the embedding for moviebot:movie:6159
# creating the embedding for moviebot:movie:6298
# creating the embedding for moviebot:movie:3416
# creating the embedding for moviebot:movie:4144
# creating the embedding for moviebot:movie:5306
# creating the embedding for moviebot:movie:8015
# creating the embedding for moviebot:movie:2892
# creating the embedding for moviebot:movie:4871
# creating the embedding for moviebot:movie:7654
# creating the embedding for moviebot:movie:3374
# creating the embedding for moviebot:movie:9602
# creating the embedding for moviebot:movie:6833
# creating the embedding for moviebot:movie:7812
# creating the embedding for moviebot:movie:2473
# creating the embedding for moviebot:movie:2877
# creating the embedding for moviebot:movie:9144
# creating the embedding for moviebot:movie:9671
# creating the embedding for moviebot:movie:9177
# creating the embedding for moviebot:movie:2831
# creating the embedding for moviebot:movie:9891
# creating the embedding for moviebot:movie:7691
# creating the embedding for moviebot:movie:4410
# creating the embedding for moviebot:movie:8034
# creating the embedding for moviebot:movie:9604
# creating the embedding for moviebot:movie:9576
# creating the embedding for moviebot:movie:6018
# creating the embedding for moviebot:movie:3701
# creating the embedding for moviebot:movie:9589
# creating the embedding for moviebot:movie:6586
# creating the embedding for moviebot:movie:3450
# creating the embedding for moviebot:movie:5973
# creating the embedding for moviebot:movie:1560
# creating the embedding for moviebot:movie:4281
# creating the embedding for moviebot:movie:6909
# creating the embedding for moviebot:movie:3082
# creating the embedding for moviebot:movie:6466
# creating the embedding for moviebot:movie:4154
# creating the embedding for moviebot:movie:93
# creating the embedding for moviebot:movie:2321
# creating the embedding for moviebot:movie:1206
# creating the embedding for moviebot:movie:6377
# creating the embedding for moviebot:movie:9260
# creating the embedding for moviebot:movie:1970
# creating the embedding for moviebot:movie:4252
# creating the embedding for moviebot:movie:5876
# creating the embedding for moviebot:movie:619
# creating the embedding for moviebot:movie:5095
# creating the embedding for moviebot:movie:766
# creating the embedding for moviebot:movie:2382
# creating the embedding for moviebot:movie:9054
# creating the embedding for moviebot:movie:8237
# creating the embedding for moviebot:movie:9326
# creating the embedding for moviebot:movie:1339
# creating the embedding for moviebot:movie:3690
# creating the embedding for moviebot:movie:4944
# creating the embedding for moviebot:movie:8663
# creating the embedding for moviebot:movie:7805
# creating the embedding for moviebot:movie:4250
# creating the embedding for moviebot:movie:9284
# creating the embedding for moviebot:movie:6599
# creating the embedding for moviebot:movie:6561
# creating the embedding for moviebot:movie:1641
# creating the embedding for moviebot:movie:6954
# creating the embedding for moviebot:movie:8770
# creating the embedding for moviebot:movie:8909
# creating the embedding for moviebot:movie:7382
# creating the embedding for moviebot:movie:3847
# creating the embedding for moviebot:movie:5555
# creating the embedding for moviebot:movie:3051
# creating the embedding for moviebot:movie:2193
# creating the embedding for moviebot:movie:3852
# creating the embedding for moviebot:movie:2063
# creating the embedding for moviebot:movie:6320
# creating the embedding for moviebot:movie:9209
# creating the embedding for moviebot:movie:2125
# creating the embedding for moviebot:movie:4807
# creating the embedding for moviebot:movie:5953
# creating the embedding for moviebot:movie:5989
# creating the embedding for moviebot:movie:8876
# creating the embedding for moviebot:movie:1226
# creating the embedding for moviebot:movie:5880
# creating the embedding for moviebot:movie:823
# creating the embedding for moviebot:movie:10013
# creating the embedding for moviebot:movie:9265
# creating the embedding for moviebot:movie:8708
# creating the embedding for moviebot:movie:253
# creating the embedding for moviebot:movie:8945
# creating the embedding for moviebot:movie:1864
# creating the embedding for moviebot:movie:953
# creating the embedding for moviebot:movie:1327
# creating the embedding for moviebot:movie:4590
# creating the embedding for moviebot:movie:5708
# creating the embedding for moviebot:movie:9251
# creating the embedding for moviebot:movie:3257
# creating the embedding for moviebot:movie:2083
# creating the embedding for moviebot:movie:897
# creating the embedding for moviebot:movie:2640
# creating the embedding for moviebot:movie:753
# creating the embedding for moviebot:movie:1501
# creating the embedding for moviebot:movie:9258
# creating the embedding for moviebot:movie:3734
# creating the embedding for moviebot:movie:1856
# creating the embedding for moviebot:movie:7308
# creating the embedding for moviebot:movie:3531
# creating the embedding for moviebot:movie:4379
# creating the embedding for moviebot:movie:4788
# creating the embedding for moviebot:movie:4495
# creating the embedding for moviebot:movie:3666
# creating the embedding for moviebot:movie:192
# creating the embedding for moviebot:movie:4674
# creating the embedding for moviebot:movie:10094
# creating the embedding for moviebot:movie:1798
# creating the embedding for moviebot:movie:9731
# creating the embedding for moviebot:movie:1983
# creating the embedding for moviebot:movie:6612
# creating the embedding for moviebot:movie:7852
# creating the embedding for moviebot:movie:3534
# creating the embedding for moviebot:movie:1225
# creating the embedding for moviebot:movie:5780
# creating the embedding for moviebot:movie:5521
# creating the embedding for moviebot:movie:7629
# creating the embedding for moviebot:movie:2116
# creating the embedding for moviebot:movie:5069
# creating the embedding for moviebot:movie:7420
# creating the embedding for moviebot:movie:9877
# creating the embedding for moviebot:movie:66
# creating the embedding for moviebot:movie:96
# creating the embedding for moviebot:movie:2411
# creating the embedding for moviebot:movie:4126
# creating the embedding for moviebot:movie:7015
# creating the embedding for moviebot:movie:8255
# creating the embedding for moviebot:movie:2212
# creating the embedding for moviebot:movie:4754
# creating the embedding for moviebot:movie:4869
# creating the embedding for moviebot:movie:7826
# creating the embedding for moviebot:movie:8171
# creating the embedding for moviebot:movie:2344
# creating the embedding for moviebot:movie:2169
# creating the embedding for moviebot:movie:3234
# creating the embedding for moviebot:movie:9716
# creating the embedding for moviebot:movie:5683
# creating the embedding for moviebot:movie:938
# creating the embedding for moviebot:movie:10062
# creating the embedding for moviebot:movie:324
# creating the embedding for moviebot:movie:2900
# creating the embedding for moviebot:movie:9387
# creating the embedding for moviebot:movie:6332
# creating the embedding for moviebot:movie:2784
# creating the embedding for moviebot:movie:9386
# creating the embedding for moviebot:movie:10153
# creating the embedding for moviebot:movie:1189
# creating the embedding for moviebot:movie:7319
# creating the embedding for moviebot:movie:18
# creating the embedding for moviebot:movie:7373
# creating the embedding for moviebot:movie:4147
# creating the embedding for moviebot:movie:3452
# creating the embedding for moviebot:movie:1815
# creating the embedding for moviebot:movie:7499
# creating the embedding for moviebot:movie:4116
# creating the embedding for moviebot:movie:7496
# creating the embedding for moviebot:movie:6635
# creating the embedding for moviebot:movie:6438
# creating the embedding for moviebot:movie:3451
# creating the embedding for moviebot:movie:2950
# creating the embedding for moviebot:movie:315
# creating the embedding for moviebot:movie:1913
# creating the embedding for moviebot:movie:7635
# creating the embedding for moviebot:movie:5222
# creating the embedding for moviebot:movie:4277
# creating the embedding for moviebot:movie:5017
# creating the embedding for moviebot:movie:5758
# creating the embedding for moviebot:movie:8027
# creating the embedding for moviebot:movie:8666
# creating the embedding for moviebot:movie:9585
# creating the embedding for moviebot:movie:6971
# creating the embedding for moviebot:movie:7545
# creating the embedding for moviebot:movie:1194
# creating the embedding for moviebot:movie:5513
# creating the embedding for moviebot:movie:3611
# creating the embedding for moviebot:movie:1939
# creating the embedding for moviebot:movie:6667
# creating the embedding for moviebot:movie:525
# creating the embedding for moviebot:movie:4541
# creating the embedding for moviebot:movie:5766
# creating the embedding for moviebot:movie:1480
# creating the embedding for moviebot:movie:3050
# creating the embedding for moviebot:movie:252
# creating the embedding for moviebot:movie:9253
# creating the embedding for moviebot:movie:2188
# creating the embedding for moviebot:movie:7735
# creating the embedding for moviebot:movie:7945
# creating the embedding for moviebot:movie:3125
# creating the embedding for moviebot:movie:9484
# creating the embedding for moviebot:movie:3921
# creating the embedding for moviebot:movie:2434
# creating the embedding for moviebot:movie:8564
# creating the embedding for moviebot:movie:5734
# creating the embedding for moviebot:movie:7828
# creating the embedding for moviebot:movie:3396
# creating the embedding for moviebot:movie:9344
# creating the embedding for moviebot:movie:8122
# creating the embedding for moviebot:movie:9558
# creating the embedding for moviebot:movie:746
# creating the embedding for moviebot:movie:4304
# creating the embedding for moviebot:movie:4823
# creating the embedding for moviebot:movie:4544
# creating the embedding for moviebot:movie:2097
# creating the embedding for moviebot:movie:5564
# creating the embedding for moviebot:movie:2666
# creating the embedding for moviebot:movie:5081
# creating the embedding for moviebot:movie:5271
# creating the embedding for moviebot:movie:7140
# creating the embedding for moviebot:movie:3137
# creating the embedding for moviebot:movie:5420
# creating the embedding for moviebot:movie:2031
# creating the embedding for moviebot:movie:4902
# creating the embedding for moviebot:movie:5247
# creating the embedding for moviebot:movie:9909
# creating the embedding for moviebot:movie:1845
# creating the embedding for moviebot:movie:4338
# creating the embedding for moviebot:movie:5997
# creating the embedding for moviebot:movie:6241
# creating the embedding for moviebot:movie:8469
# creating the embedding for moviebot:movie:2468
# creating the embedding for moviebot:movie:5940
# creating the embedding for moviebot:movie:9074
# creating the embedding for moviebot:movie:4685
# creating the embedding for moviebot:movie:6098
# creating the embedding for moviebot:movie:4161
# creating the embedding for moviebot:movie:2328
# creating the embedding for moviebot:movie:1176
# creating the embedding for moviebot:movie:3560
# creating the embedding for moviebot:movie:2529
# creating the embedding for moviebot:movie:9733
# creating the embedding for moviebot:movie:7180
# creating the embedding for moviebot:movie:9510
# creating the embedding for moviebot:movie:945
# creating the embedding for moviebot:movie:6416
# creating the embedding for moviebot:movie:526
# creating the embedding for moviebot:movie:7009
# creating the embedding for moviebot:movie:1651
# creating the embedding for moviebot:movie:1731
# creating the embedding for moviebot:movie:8008
# creating the embedding for moviebot:movie:3892
# creating the embedding for moviebot:movie:5365
# creating the embedding for moviebot:movie:9249
# creating the embedding for moviebot:movie:1766
# creating the embedding for moviebot:movie:832
# creating the embedding for moviebot:movie:6545
# creating the embedding for moviebot:movie:2778
# creating the embedding for moviebot:movie:10123
# creating the embedding for moviebot:movie:8847
# creating the embedding for moviebot:movie:4079
# creating the embedding for moviebot:movie:9434
# creating the embedding for moviebot:movie:9266
# creating the embedding for moviebot:movie:9250
# creating the embedding for moviebot:movie:5031
# creating the embedding for moviebot:movie:6210
# creating the embedding for moviebot:movie:1274
# creating the embedding for moviebot:movie:8204
# creating the embedding for moviebot:movie:10112
# creating the embedding for moviebot:movie:2835
# creating the embedding for moviebot:movie:9954
# creating the embedding for moviebot:movie:9798
# creating the embedding for moviebot:movie:6976
# creating the embedding for moviebot:movie:1267
# creating the embedding for moviebot:movie:1047
# creating the embedding for moviebot:movie:6600
# creating the embedding for moviebot:movie:3122
# creating the embedding for moviebot:movie:9376
# creating the embedding for moviebot:movie:9043
# creating the embedding for moviebot:movie:2958
# creating the embedding for moviebot:movie:1015
# creating the embedding for moviebot:movie:2242
# creating the embedding for moviebot:movie:5497
# creating the embedding for moviebot:movie:10018
# creating the embedding for moviebot:movie:8740
# creating the embedding for moviebot:movie:4545
# creating the embedding for moviebot:movie:5962
# creating the embedding for moviebot:movie:7569
# creating the embedding for moviebot:movie:7864
# creating the embedding for moviebot:movie:5455
# creating the embedding for moviebot:movie:336
# creating the embedding for moviebot:movie:8404
# creating the embedding for moviebot:movie:1266
# creating the embedding for moviebot:movie:2689
# creating the embedding for moviebot:movie:1869
# creating the embedding for moviebot:movie:1569
# creating the embedding for moviebot:movie:5559
# creating the embedding for moviebot:movie:534
# creating the embedding for moviebot:movie:4191
# creating the embedding for moviebot:movie:3456
# creating the embedding for moviebot:movie:9019
# creating the embedding for moviebot:movie:8511
# creating the embedding for moviebot:movie:8245
# creating the embedding for moviebot:movie:5392
# creating the embedding for moviebot:movie:6183
# creating the embedding for moviebot:movie:6418
# creating the embedding for moviebot:movie:6349
# creating the embedding for moviebot:movie:7772
# creating the embedding for moviebot:movie:4443
# creating the embedding for moviebot:movie:5701
# creating the embedding for moviebot:movie:3912
# creating the embedding for moviebot:movie:5500
# creating the embedding for moviebot:movie:5868
# creating the embedding for moviebot:movie:9607
# creating the embedding for moviebot:movie:3848
# creating the embedding for moviebot:movie:5364
# creating the embedding for moviebot:movie:7158
# creating the embedding for moviebot:movie:827
# creating the embedding for moviebot:movie:6613
# creating the embedding for moviebot:movie:1
# creating the embedding for moviebot:movie:9633
# creating the embedding for moviebot:movie:875
# creating the embedding for moviebot:movie:4010
# creating the embedding for moviebot:movie:8690
# creating the embedding for moviebot:movie:4172
# creating the embedding for moviebot:movie:2210
# creating the embedding for moviebot:movie:5838
# creating the embedding for moviebot:movie:2432
# creating the embedding for moviebot:movie:6348
# creating the embedding for moviebot:movie:2894
# creating the embedding for moviebot:movie:4884
# creating the embedding for moviebot:movie:932
# creating the embedding for moviebot:movie:1162
# creating the embedding for moviebot:movie:7981
# creating the embedding for moviebot:movie:3143
# creating the embedding for moviebot:movie:6875
# creating the embedding for moviebot:movie:2392
# creating the embedding for moviebot:movie:4400
# creating the embedding for moviebot:movie:8930
# creating the embedding for moviebot:movie:5703
# creating the embedding for moviebot:movie:9451
# creating the embedding for moviebot:movie:951
# creating the embedding for moviebot:movie:6614
# creating the embedding for moviebot:movie:9816
# creating the embedding for moviebot:movie:6946
# creating the embedding for moviebot:movie:5923
# creating the embedding for moviebot:movie:2100
# creating the embedding for moviebot:movie:2036
# creating the embedding for moviebot:movie:5461
# creating the embedding for moviebot:movie:523
# creating the embedding for moviebot:movie:8217
# creating the embedding for moviebot:movie:5506
# creating the embedding for moviebot:movie:6000
# creating the embedding for moviebot:movie:3383
# creating the embedding for moviebot:movie:6639
# creating the embedding for moviebot:movie:181
# creating the embedding for moviebot:movie:4698
# creating the embedding for moviebot:movie:9801
# creating the embedding for moviebot:movie:8151
# creating the embedding for moviebot:movie:69
# creating the embedding for moviebot:movie:4148
# creating the embedding for moviebot:movie:6169
# creating the embedding for moviebot:movie:7424
# creating the embedding for moviebot:movie:9400
# creating the embedding for moviebot:movie:5468
# creating the embedding for moviebot:movie:8737
# creating the embedding for moviebot:movie:6716
# creating the embedding for moviebot:movie:3703
# creating the embedding for moviebot:movie:7760
# creating the embedding for moviebot:movie:7814
# creating the embedding for moviebot:movie:2492
# creating the embedding for moviebot:movie:4670
# creating the embedding for moviebot:movie:4975
# creating the embedding for moviebot:movie:5963
# creating the embedding for moviebot:movie:8758
# creating the embedding for moviebot:movie:7738
# creating the embedding for moviebot:movie:4286
# creating the embedding for moviebot:movie:1896
# creating the embedding for moviebot:movie:9295
# creating the embedding for moviebot:movie:1830
# creating the embedding for moviebot:movie:1020
# creating the embedding for moviebot:movie:3139
# creating the embedding for moviebot:movie:8550
# creating the embedding for moviebot:movie:2522
# creating the embedding for moviebot:movie:787
# creating the embedding for moviebot:movie:1337
# creating the embedding for moviebot:movie:4582
# creating the embedding for moviebot:movie:2656
# creating the embedding for moviebot:movie:5384
# creating the embedding for moviebot:movie:1507
# creating the embedding for moviebot:movie:7147
# creating the embedding for moviebot:movie:5405
# creating the embedding for moviebot:movie:7234
# creating the embedding for moviebot:movie:9296
# creating the embedding for moviebot:movie:6688
# creating the embedding for moviebot:movie:8075
# creating the embedding for moviebot:movie:9943
# creating the embedding for moviebot:movie:3407
# creating the embedding for moviebot:movie:10039
# creating the embedding for moviebot:movie:5839
# creating the embedding for moviebot:movie:2701
# creating the embedding for moviebot:movie:3055
# creating the embedding for moviebot:movie:5832
# creating the embedding for moviebot:movie:699
# creating the embedding for moviebot:movie:6351
# creating the embedding for moviebot:movie:3820
# creating the embedding for moviebot:movie:2248
# creating the embedding for moviebot:movie:5173
# creating the embedding for moviebot:movie:6818
# creating the embedding for moviebot:movie:2524
# creating the embedding for moviebot:movie:9409
# creating the embedding for moviebot:movie:768
# creating the embedding for moviebot:movie:5752
# creating the embedding for moviebot:movie:3238
# creating the embedding for moviebot:movie:6424
# creating the embedding for moviebot:movie:9319
# creating the embedding for moviebot:movie:1464
# creating the embedding for moviebot:movie:7589
# creating the embedding for moviebot:movie:1286
# creating the embedding for moviebot:movie:9637
# creating the embedding for moviebot:movie:411
# creating the embedding for moviebot:movie:1409
# creating the embedding for moviebot:movie:8944
# creating the embedding for moviebot:movie:2552
# creating the embedding for moviebot:movie:5641
# creating the embedding for moviebot:movie:955
# creating the embedding for moviebot:movie:2799
# creating the embedding for moviebot:movie:6827
# creating the embedding for moviebot:movie:7873
# creating the embedding for moviebot:movie:6695
# creating the embedding for moviebot:movie:5814
# creating the embedding for moviebot:movie:7457
# creating the embedding for moviebot:movie:749
# creating the embedding for moviebot:movie:7437
# creating the embedding for moviebot:movie:6399
# creating the embedding for moviebot:movie:9352
# creating the embedding for moviebot:movie:8320
# creating the embedding for moviebot:movie:8533
# creating the embedding for moviebot:movie:1132
# creating the embedding for moviebot:movie:4300
# creating the embedding for moviebot:movie:3950
# creating the embedding for moviebot:movie:43
# creating the embedding for moviebot:movie:5979
# creating the embedding for moviebot:movie:99
# creating the embedding for moviebot:movie:7066
# creating the embedding for moviebot:movie:8937
# creating the embedding for moviebot:movie:7021
# creating the embedding for moviebot:movie:6028
# creating the embedding for moviebot:movie:1784
# creating the embedding for moviebot:movie:7953
# creating the embedding for moviebot:movie:2672
# creating the embedding for moviebot:movie:5771
# creating the embedding for moviebot:movie:6133
# creating the embedding for moviebot:movie:7911
# creating the embedding for moviebot:movie:6693
# creating the embedding for moviebot:movie:6905
# creating the embedding for moviebot:movie:115
# creating the embedding for moviebot:movie:1662
# creating the embedding for moviebot:movie:7242
# creating the embedding for moviebot:movie:3691
# creating the embedding for moviebot:movie:7561
# creating the embedding for moviebot:movie:3541
# creating the embedding for moviebot:movie:5999
# creating the embedding for moviebot:movie:3085
# creating the embedding for moviebot:movie:8047
# creating the embedding for moviebot:movie:5637
# creating the embedding for moviebot:movie:4484
# creating the embedding for moviebot:movie:1431
# creating the embedding for moviebot:movie:3013
# creating the embedding for moviebot:movie:6788
# creating the embedding for moviebot:movie:2542
# creating the embedding for moviebot:movie:7931
# creating the embedding for moviebot:movie:8854
# creating the embedding for moviebot:movie:176
# creating the embedding for moviebot:movie:2876
# creating the embedding for moviebot:movie:3064
# creating the embedding for moviebot:movie:631
# creating the embedding for moviebot:movie:8427
# creating the embedding for moviebot:movie:238
# creating the embedding for moviebot:movie:7202
# creating the embedding for moviebot:movie:3295
# creating the embedding for moviebot:movie:3341
# creating the embedding for moviebot:movie:7539
# creating the embedding for moviebot:movie:8468
# creating the embedding for moviebot:movie:3115
# creating the embedding for moviebot:movie:6037
# creating the embedding for moviebot:movie:10049
# creating the embedding for moviebot:movie:7839
# creating the embedding for moviebot:movie:5006
# creating the embedding for moviebot:movie:2154
# creating the embedding for moviebot:movie:6408
# creating the embedding for moviebot:movie:226
# creating the embedding for moviebot:movie:7712
# creating the embedding for moviebot:movie:4129
# creating the embedding for moviebot:movie:1955
# creating the embedding for moviebot:movie:6380
# creating the embedding for moviebot:movie:7316
# creating the embedding for moviebot:movie:9367
# creating the embedding for moviebot:movie:9439
# creating the embedding for moviebot:movie:71
# creating the embedding for moviebot:movie:3654
# creating the embedding for moviebot:movie:3676
# creating the embedding for moviebot:movie:8959
# creating the embedding for moviebot:movie:7557
# creating the embedding for moviebot:movie:2813
# creating the embedding for moviebot:movie:7020
# creating the embedding for moviebot:movie:2679
# creating the embedding for moviebot:movie:8349
# creating the embedding for moviebot:movie:3173
# creating the embedding for moviebot:movie:5622
# creating the embedding for moviebot:movie:658
# creating the embedding for moviebot:movie:3903
# creating the embedding for moviebot:movie:7878
# creating the embedding for moviebot:movie:6259
# creating the embedding for moviebot:movie:287
# creating the embedding for moviebot:movie:5047
# creating the embedding for moviebot:movie:1643
# creating the embedding for moviebot:movie:5775
# creating the embedding for moviebot:movie:1543
# creating the embedding for moviebot:movie:4091
# creating the embedding for moviebot:movie:6746
# creating the embedding for moviebot:movie:3518
# creating the embedding for moviebot:movie:7004
# creating the embedding for moviebot:movie:3279
# creating the embedding for moviebot:movie:4961
# creating the embedding for moviebot:movie:5000
# creating the embedding for moviebot:movie:581
# creating the embedding for moviebot:movie:5003
# creating the embedding for moviebot:movie:947
# creating the embedding for moviebot:movie:6899
# creating the embedding for moviebot:movie:4547
# creating the embedding for moviebot:movie:4109
# creating the embedding for moviebot:movie:1358
# creating the embedding for moviebot:movie:8804
# creating the embedding for moviebot:movie:1011
# creating the embedding for moviebot:movie:346
# creating the embedding for moviebot:movie:5333
# creating the embedding for moviebot:movie:399
# creating the embedding for moviebot:movie:7035
# creating the embedding for moviebot:movie:9908
# creating the embedding for moviebot:movie:756
# creating the embedding for moviebot:movie:2575
# creating the embedding for moviebot:movie:1447
# creating the embedding for moviebot:movie:4890
# creating the embedding for moviebot:movie:9523
# creating the embedding for moviebot:movie:2230
# creating the embedding for moviebot:movie:2373
# creating the embedding for moviebot:movie:5503
# creating the embedding for moviebot:movie:7518
# creating the embedding for moviebot:movie:6334
# creating the embedding for moviebot:movie:7288
# creating the embedding for moviebot:movie:9939
# creating the embedding for moviebot:movie:1618
# creating the embedding for moviebot:movie:7893
# creating the embedding for moviebot:movie:5801
# creating the embedding for moviebot:movie:2121
# creating the embedding for moviebot:movie:5501
# creating the embedding for moviebot:movie:3114
# creating the embedding for moviebot:movie:3272
# creating the embedding for moviebot:movie:6379
# creating the embedding for moviebot:movie:4303
# creating the embedding for moviebot:movie:4640
# creating the embedding for moviebot:movie:8490
# creating the embedding for moviebot:movie:9975
# creating the embedding for moviebot:movie:8926
# creating the embedding for moviebot:movie:779
# creating the embedding for moviebot:movie:1515
# creating the embedding for moviebot:movie:2058
# creating the embedding for moviebot:movie:1954
# creating the embedding for moviebot:movie:303
# creating the embedding for moviebot:movie:5458
# creating the embedding for moviebot:movie:1334
# creating the embedding for moviebot:movie:3962
# creating the embedding for moviebot:movie:5594
# creating the embedding for moviebot:movie:4937
# creating the embedding for moviebot:movie:4815
# creating the embedding for moviebot:movie:3762
# creating the embedding for moviebot:movie:1052
# creating the embedding for moviebot:movie:5447
# creating the embedding for moviebot:movie:7058
# creating the embedding for moviebot:movie:2726
# creating the embedding for moviebot:movie:1161
# creating the embedding for moviebot:movie:644
# creating the embedding for moviebot:movie:145
# ...
# creating the embedding for moviebot:movie:6092
# creating the embedding for moviebot:movie:8954
# creating the embedding for moviebot:movie:5530
# creating the embedding for moviebot:movie:5665
# creating the embedding for moviebot:movie:6012
# creating the embedding for moviebot:movie:10139
# creating the embedding for moviebot:movie:1945
# creating the embedding for moviebot:movie:7093
# creating the embedding for moviebot:movie:3947
# creating the embedding for moviebot:movie:7513
# creating the embedding for moviebot:movie:8067
# creating the embedding for moviebot:movie:2761
# creating the embedding for moviebot:movie:6442
# creating the embedding for moviebot:movie:2787
# creating the embedding for moviebot:movie:8417
# creating the embedding for moviebot:movie:2981
# creating the embedding for moviebot:movie:1227
# creating the embedding for moviebot:movie:8712
# creating the embedding for moviebot:movie:3482
# creating the embedding for moviebot:movie:1004
# creating the embedding for moviebot:movie:7623
# creating the embedding for moviebot:movie:8401
# creating the embedding for moviebot:movie:925
# creating the embedding for moviebot:movie:6328
# creating the embedding for moviebot:movie:800
# creating the embedding for moviebot:movie:3557
# creating the embedding for moviebot:movie:228
# creating the embedding for moviebot:movie:2049
# creating the embedding for moviebot:movie:7500
# creating the embedding for moviebot:movie:5113
# creating the embedding for moviebot:movie:1844
# creating the embedding for moviebot:movie:10086
# creating the embedding for moviebot:movie:4611
# creating the embedding for moviebot:movie:9331
# creating the embedding for moviebot:movie:6445
# creating the embedding for moviebot:movie:8227
# creating the embedding for moviebot:movie:2103
# creating the embedding for moviebot:movie:1278
# creating the embedding for moviebot:movie:6093
# creating the embedding for moviebot:movie:313
# creating the embedding for moviebot:movie:6837
# creating the embedding for moviebot:movie:1149
# creating the embedding for moviebot:movie:1659
# creating the embedding for moviebot:movie:7273
# creating the embedding for moviebot:movie:4525
# creating the embedding for moviebot:movie:662
# creating the embedding for moviebot:movie:4972
# creating the embedding for moviebot:movie:6553
# creating the embedding for moviebot:movie:5016
# creating the embedding for moviebot:movie:425
# creating the embedding for moviebot:movie:2750
# creating the embedding for moviebot:movie:2865
# creating the embedding for moviebot:movie:4762
# creating the embedding for moviebot:movie:6632
# creating the embedding for moviebot:movie:10087
# creating the embedding for moviebot:movie:5942
# creating the embedding for moviebot:movie:1629
# creating the embedding for moviebot:movie:4493
# creating the embedding for moviebot:movie:1364
# creating the embedding for moviebot:movie:1840
# creating the embedding for moviebot:movie:3613
# creating the embedding for moviebot:movie:4851
# creating the embedding for moviebot:movie:6958
# creating the embedding for moviebot:movie:8535
# creating the embedding for moviebot:movie:4963
# creating the embedding for moviebot:movie:6367
# creating the embedding for moviebot:movie:1039
# creating the embedding for moviebot:movie:1202
# creating the embedding for moviebot:movie:9222
# creating the embedding for moviebot:movie:168
# creating the embedding for moviebot:movie:1748
# creating the embedding for moviebot:movie:9920
# creating the embedding for moviebot:movie:3017
# creating the embedding for moviebot:movie:6326
# creating the embedding for moviebot:movie:4514
# creating the embedding for moviebot:movie:8382
# creating the embedding for moviebot:movie:2147
# creating the embedding for moviebot:movie:9342
# creating the embedding for moviebot:movie:9164
# creating the embedding for moviebot:movie:5647
# creating the embedding for moviebot:movie:2883
# creating the embedding for moviebot:movie:2022
# creating the embedding for moviebot:movie:992
# creating the embedding for moviebot:movie:8433
# creating the embedding for moviebot:movie:4375
# creating the embedding for moviebot:movie:843
# creating the embedding for moviebot:movie:4474
# creating the embedding for moviebot:movie:4179
# creating the embedding for moviebot:movie:4231
# creating the embedding for moviebot:movie:5117
# creating the embedding for moviebot:movie:9313
# creating the embedding for moviebot:movie:939
# creating the embedding for moviebot:movie:36
# creating the embedding for moviebot:movie:9949
# creating the embedding for moviebot:movie:3057
# creating the embedding for moviebot:movie:2470
# creating the embedding for moviebot:movie:1059
# creating the embedding for moviebot:movie:7012
# creating the embedding for moviebot:movie:8046
# creating the embedding for moviebot:movie:1822
# creating the embedding for moviebot:movie:3001
# creating the embedding for moviebot:movie:6075
# creating the embedding for moviebot:movie:4013
# creating the embedding for moviebot:movie:8640
# creating the embedding for moviebot:movie:495
# creating the embedding for moviebot:movie:3399
# creating the embedding for moviebot:movie:2282
# creating the embedding for moviebot:movie:6792
# creating the embedding for moviebot:movie:9479
# creating the embedding for moviebot:movie:9254
# creating the embedding for moviebot:movie:1795
# creating the embedding for moviebot:movie:9569
# creating the embedding for moviebot:movie:3661
# creating the embedding for moviebot:movie:5538
# creating the embedding for moviebot:movie:8826
# creating the embedding for moviebot:movie:8760
# creating the embedding for moviebot:movie:3717
# creating the embedding for moviebot:movie:2397
# creating the embedding for moviebot:movie:5894
# creating the embedding for moviebot:movie:685
# creating the embedding for moviebot:movie:5217
# creating the embedding for moviebot:movie:1535
# creating the embedding for moviebot:movie:2270
# creating the embedding for moviebot:movie:4631
# creating the embedding for moviebot:movie:19
# creating the embedding for moviebot:movie:7833
# creating the embedding for moviebot:movie:3935
# creating the embedding for moviebot:movie:9740
# creating the embedding for moviebot:movie:8406
# creating the embedding for moviebot:movie:5005
# creating the embedding for moviebot:movie:9749
# creating the embedding for moviebot:movie:6902
# creating the embedding for moviebot:movie:557
# creating the embedding for moviebot:movie:1511
# creating the embedding for moviebot:movie:8906
# creating the embedding for moviebot:movie:1130
# creating the embedding for moviebot:movie:7497
# creating the embedding for moviebot:movie:8762
# creating the embedding for moviebot:movie:4056
# creating the embedding for moviebot:movie:4142
# creating the embedding for moviebot:movie:3835
# creating the embedding for moviebot:movie:1706
# creating the embedding for moviebot:movie:1186
# creating the embedding for moviebot:movie:3553
# creating the embedding for moviebot:movie:299
# creating the embedding for moviebot:movie:8378
# creating the embedding for moviebot:movie:5467
# creating the embedding for moviebot:movie:4325
# creating the embedding for moviebot:movie:6392
# creating the embedding for moviebot:movie:6376
# creating the embedding for moviebot:movie:7972
# creating the embedding for moviebot:movie:8146
# creating the embedding for moviebot:movie:1579
# creating the embedding for moviebot:movie:5246
# creating the embedding for moviebot:movie:6936
# creating the embedding for moviebot:movie:811
# creating the embedding for moviebot:movie:650
# creating the embedding for moviebot:movie:3822
# creating the embedding for moviebot:movie:1836
# creating the embedding for moviebot:movie:618
# creating the embedding for moviebot:movie:10041
# creating the embedding for moviebot:movie:8335
# creating the embedding for moviebot:movie:8855
# creating the embedding for moviebot:movie:387
# creating the embedding for moviebot:movie:394
# creating the embedding for moviebot:movie:8085
# creating the embedding for moviebot:movie:8830
# creating the embedding for moviebot:movie:3210
# creating the embedding for moviebot:movie:1693
# creating the embedding for moviebot:movie:7182
# creating the embedding for moviebot:movie:9547
# creating the embedding for moviebot:movie:7206
# creating the embedding for moviebot:movie:1855
# creating the embedding for moviebot:movie:8095
# creating the embedding for moviebot:movie:55
# creating the embedding for moviebot:movie:8332
# creating the embedding for moviebot:movie:321
# creating the embedding for moviebot:movie:9948
# creating the embedding for moviebot:movie:9923
# creating the embedding for moviebot:movie:5375
# creating the embedding for moviebot:movie:3713
# creating the embedding for moviebot:movie:7630
# creating the embedding for moviebot:movie:9489
# creating the embedding for moviebot:movie:4509
# creating the embedding for moviebot:movie:3996
# creating the embedding for moviebot:movie:4928
# creating the embedding for moviebot:movie:2055
# creating the embedding for moviebot:movie:8943
# creating the embedding for moviebot:movie:6013
# creating the embedding for moviebot:movie:5757
# creating the embedding for moviebot:movie:2566
# creating the embedding for moviebot:movie:4237
# creating the embedding for moviebot:movie:8617
# creating the embedding for moviebot:movie:4038
# creating the embedding for moviebot:movie:4224
# creating the embedding for moviebot:movie:2857
# creating the embedding for moviebot:movie:537
# creating the embedding for moviebot:movie:1692
# creating the embedding for moviebot:movie:5054
# creating the embedding for moviebot:movie:2333
# creating the embedding for moviebot:movie:8624
# creating the embedding for moviebot:movie:5632
# creating the embedding for moviebot:movie:4451
# creating the embedding for moviebot:movie:1208
# creating the embedding for moviebot:movie:6048
# creating the embedding for moviebot:movie:8264
# creating the embedding for moviebot:movie:5165
# creating the embedding for moviebot:movie:7675
# creating the embedding for moviebot:movie:893
# creating the embedding for moviebot:movie:1221
# creating the embedding for moviebot:movie:2709
# creating the embedding for moviebot:movie:1675
# creating the embedding for moviebot:movie:9468
# creating the embedding for moviebot:movie:9442
# creating the embedding for moviebot:movie:2839
# creating the embedding for moviebot:movie:6138
# creating the embedding for moviebot:movie:9945
# creating the embedding for moviebot:movie:9317
# creating the embedding for moviebot:movie:10002
# creating the embedding for moviebot:movie:7977
# creating the embedding for moviebot:movie:2517
# creating the embedding for moviebot:movie:883
# creating the embedding for moviebot:movie:3000
# creating the embedding for moviebot:movie:10014
# creating the embedding for moviebot:movie:4750
# creating the embedding for moviebot:movie:9734
# creating the embedding for moviebot:movie:9485
# creating the embedding for moviebot:movie:6531
# creating the embedding for moviebot:movie:3350
# creating the embedding for moviebot:movie:7670
# creating the embedding for moviebot:movie:8572
# creating the embedding for moviebot:movie:6369
# creating the embedding for moviebot:movie:9167
# creating the embedding for moviebot:movie:3711
# creating the embedding for moviebot:movie:5947
# creating the embedding for moviebot:movie:3787
# creating the embedding for moviebot:movie:2632
# creating the embedding for moviebot:movie:6394
# creating the embedding for moviebot:movie:3054
# creating the embedding for moviebot:movie:8889
# creating the embedding for moviebot:movie:3791
# creating the embedding for moviebot:movie:1506
# creating the embedding for moviebot:movie:3154
# creating the embedding for moviebot:movie:4633
# creating the embedding for moviebot:movie:7883
# creating the embedding for moviebot:movie:3672
# creating the embedding for moviebot:movie:3346
# creating the embedding for moviebot:movie:4324
# creating the embedding for moviebot:movie:8049
# creating the embedding for moviebot:movie:4371
# creating the embedding for moviebot:movie:1841
# creating the embedding for moviebot:movie:2581
# creating the embedding for moviebot:movie:8650
# creating the embedding for moviebot:movie:1086
# creating the embedding for moviebot:movie:6142
# creating the embedding for moviebot:movie:1317
# creating the embedding for moviebot:movie:617
# creating the embedding for moviebot:movie:8299
# creating the embedding for moviebot:movie:7321
# creating the embedding for moviebot:movie:8392
# creating the embedding for moviebot:movie:8273
# creating the embedding for moviebot:movie:3266
# creating the embedding for moviebot:movie:182
# creating the embedding for moviebot:movie:7026
# creating the embedding for moviebot:movie:6032
# creating the embedding for moviebot:movie:2902
# creating the embedding for moviebot:movie:6877
# creating the embedding for moviebot:movie:33
# creating the embedding for moviebot:movie:4337
# creating the embedding for moviebot:movie:2102
# creating the embedding for moviebot:movie:8836
# creating the embedding for moviebot:movie:9202
# creating the embedding for moviebot:movie:1231
# creating the embedding for moviebot:movie:9757
# creating the embedding for moviebot:movie:9246
# creating the embedding for moviebot:movie:8981
# creating the embedding for moviebot:movie:4434
# creating the embedding for moviebot:movie:163
# creating the embedding for moviebot:movie:8297
# creating the embedding for moviebot:movie:4475
# creating the embedding for moviebot:movie:7509
# creating the embedding for moviebot:movie:1397
# creating the embedding for moviebot:movie:6739
# creating the embedding for moviebot:movie:3022
# creating the embedding for moviebot:movie:9350
# creating the embedding for moviebot:movie:4163
# creating the embedding for moviebot:movie:1634
# creating the embedding for moviebot:movie:5278
# creating the embedding for moviebot:movie:7006
# creating the embedding for moviebot:movie:7351
# creating the embedding for moviebot:movie:10129
# creating the embedding for moviebot:movie:191
# creating the embedding for moviebot:movie:9679
# creating the embedding for moviebot:movie:819
# creating the embedding for moviebot:movie:4059
# creating the embedding for moviebot:movie:2378
# creating the embedding for moviebot:movie:3522
# creating the embedding for moviebot:movie:1808
# creating the embedding for moviebot:movie:7830
# creating the embedding for moviebot:movie:4630
# creating the embedding for moviebot:movie:1444
# creating the embedding for moviebot:movie:10015
# creating the embedding for moviebot:movie:1009
# creating the embedding for moviebot:movie:6077
# creating the embedding for moviebot:movie:2026
# creating the embedding for moviebot:movie:7456
# creating the embedding for moviebot:movie:5565
# creating the embedding for moviebot:movie:4082
# creating the embedding for moviebot:movie:6604
# creating the embedding for moviebot:movie:8001
# creating the embedding for moviebot:movie:927
# creating the embedding for moviebot:movie:5531
# creating the embedding for moviebot:movie:5315
# creating the embedding for moviebot:movie:9122
# creating the embedding for moviebot:movie:389
# creating the embedding for moviebot:movie:8445
# creating the embedding for moviebot:movie:460
# creating the embedding for moviebot:movie:2249
# creating the embedding for moviebot:movie:7848
# creating the embedding for moviebot:movie:2613
# creating the embedding for moviebot:movie:4086
# creating the embedding for moviebot:movie:3991
# creating the embedding for moviebot:movie:2928
# creating the embedding for moviebot:movie:5931
# creating the embedding for moviebot:movie:3214
# creating the embedding for moviebot:movie:443
# creating the embedding for moviebot:movie:2407
# creating the embedding for moviebot:movie:2718
# creating the embedding for moviebot:movie:5805
# creating the embedding for moviebot:movie:6264
# creating the embedding for moviebot:movie:7884
# creating the embedding for moviebot:movie:6105
# creating the embedding for moviebot:movie:3744
# creating the embedding for moviebot:movie:9077
# creating the embedding for moviebot:movie:4183
# creating the embedding for moviebot:movie:5651
# creating the embedding for moviebot:movie:5689
# creating the embedding for moviebot:movie:1232
# creating the embedding for moviebot:movie:5835
# creating the embedding for moviebot:movie:1134
# creating the embedding for moviebot:movie:4401

# %% [markdown]
# #### Checkpoint - vamos entender o que temos no Redis agora
#
# Nós criamos o embedding usando outros atributos do filme, e guardamos esse "fingerprint" junto do próprio documento JSON que representa cada filme.
#
# Olha só como ficou agora:

# %%
import json

movie_with_embedding = redis.json().get("moviebot:movie:1")
pretty_json = json.dumps(movie_with_embedding, indent=4, ensure_ascii=False)
print(pretty_json)
# Out:
# {
#     "names": "Avatar: The Way of Water",
#     "date_x": "12/15/2022 ",
#     "score": "78.0",
#     "genre": "Science Fiction, Adventure, Action",
#     "overview": "Set more than a decade after the events of the first film, learn the story of the Sully family (Jake, Neytiri, and their kids), the trouble that follows them, the lengths they go to keep each other safe, the battles they fight to stay alive, and the tragedies they endure.",
#     "crew": "Sam Worthington, Jake Sully, Zoe Saldaña, Neytiri, Sigourney Weaver, Kiri / Dr. Grace Augustine, Stephen Lang, Colonel Miles Quaritch, Kate Winslet, Ronal, Cliff Curtis, Tonowari, Joel David Moore, Norm Spellman, CCH Pounder, Mo'at, Edie Falco, General Frances Ardmore",
#     "orig_title": "Avatar: The Way of Water",
#     "status": " Released",
#     "orig_lang": " English",
#     "budget_x": "460000000.0",
#     "revenue": "2316794914.0",
#     "country": "AU",
#     "overview_embedding": [
#         -0.07662265002727509,
#         -0.002546886680647731,
#         -0.032196078449487686,
#         0.011513849720358849,
#         -0.08130208402872086,
#         0.049115490168333054,
#         -0.0099481213837862,
#         -0.02208397537469864,
#         0.02739502675831318,
#         -0.04375659301877022,
#         0.023889271542429924,
#         -0.04147323966026306,
#         0.011361869983375072,
#         0.08310453593730927,
#         -0.10652364790439606,
#         0.053585201501846313,
#         -0.019514326006174088,
#         -0.01200500037521124,
#         -0.003065006574615836,
#         -0.025822577998042107,
#         -0.02274660207331181,
#         0.012450428679585457,
#         -0.018093343824148175,
#         -0.01194259151816368,
#         -0.0317913256585598,
#         0.06833594292402267,
#         0.0573287196457386,
#         0.01928727887570858,
#         -0.11408308893442154,
#         -0.015833929181098938,
#         0.014425849542021751,
#         0.050749488174915314,
#         -0.01128885429352522,
#         -0.06436078995466232,
#         -0.005351260770112276,
#         0.06897943466901779,
#         -0.04033862426877022,
#         -0.08665157109498978,
#         -0.047952622175216675,
#         -0.030509717762470245,
#         -4.8694073484512046e-05,
#         0.008052075281739235,
#         0.04419170320034027,
#         -0.09299507737159728,
#         0.04968618229031563,
#         -0.10186827182769775,
#         -0.05129854381084442,
#         -0.06849323958158493,
#         0.07689478248357773,
#         0.04335808381438255,
#         -0.07744242250919342,
#         -0.06359826028347015,
#         0.022780276834964752,
#         0.04960134997963905,
#         0.018070390447974205,
#         -0.06655555218458176,
#         0.02521934919059277,
#         -0.063631072640419,
#         0.01453257817775011,
#         -0.04045600071549416,
#         -0.008525678887963295,
#         -0.02232223190367222,
#         -0.04592694714665413,
#         -0.03416340425610542,
#         0.048781659454107285,
#         -0.06118419021368027,
#         -0.04187376797199249,
#         0.02082422375679016,
#         -0.04380170255899429,
#         -0.031595297157764435,
#         -0.10433300584554672,
#         0.057986024767160416,
#         0.03813394904136658,
#         -0.03529640659689903,
#         -0.08201991766691208,
#         -0.00042825343552976847,
#         -0.021529506891965863,
#         0.02290548011660576,
#         0.01385097298771143,
#         -0.03948625922203064,
#         0.031216878443956375,
#         -0.08388956636190414,
#         0.03014911711215973,
#         0.03435717523097992,
#         0.050640951842069626,
#         0.03200005739927292,
#         0.054863933473825455,
#         -0.02398698404431343,
#         0.031068073585629463,
#         0.03891849145293236,
#         -0.1981089860200882,
#         -0.04819174483418465,
#         0.0711372122168541,
#         0.02544535882771015,
#         0.06596946716308594,
#         0.03006712719798088,
#         -0.066232830286026,
#         -0.0013933413429185748,
#         -0.0536486841738224,
#         0.0005620724405162036,
#         0.04038370028138161,
#         -0.04708095267415047,
#         -0.014315424486994743,
#         -0.017777973785996437,
#         0.1517263799905777,
#         -0.03202557563781738,
#         0.09614230692386629,
#         0.007700841408222914,
#         0.019697051495313644,
#         -0.04191427677869797,
#         -0.06890556216239929,
#         -0.031259190291166306,
#         0.019560987129807472,
#         0.09216766804456712,
#         0.040985576808452606,
#         -0.004341695457696915,
#         0.05663248896598816,
#         0.03333662077784538,
#         -0.02995951846241951,
#         0.02416965365409851,
#         0.04071492701768875,
#         -0.0020263316109776497,
#         -0.02560248970985413,
#         -0.01949172466993332,
#         0.08543016016483307,
#         0.018115559592843056,
#         0.012731329537928104,
#         3.6401247035165764e-33,
#         0.07567740976810455,
#         -0.012274249456822872,
#         0.05132998898625374,
#         0.08647755533456802,
#         0.04080726206302643,
#         -0.03502633422613144,
#         -0.08287657797336578,
#         0.03931679576635361,
#         -0.06687869131565094,
#         -0.009937429800629616,
#         -0.1480391025543213,
#         -0.024529792368412014,
#         -0.07731717824935913,
#         0.024073738604784012,
#         -0.0020866338163614273,
#         -0.013883025385439396,
#         -0.05180713161826134,
#         -0.0076966118067502975,
#         0.01834988221526146,
#         -0.026484714820981026,
#         -0.053124479949474335,
#         -0.00521997082978487,
#         -0.08597372472286224,
#         -0.07455479353666306,
#         -0.034990664571523666,
#         -0.07460901141166687,
#         -0.003771641058847308,
#         0.03643617779016495,
#         -0.0325641855597496,
#         0.0018315567867830396,
#         0.035073354840278625,
#         0.04040221869945526,
#         0.06047094613313675,
#         0.010862525552511215,
#         0.05211157351732254,
#         -0.011147676035761831,
#         -0.003181047737598419,
#         0.00964924693107605,
#         -0.018708238378167152,
#         0.11506699025630952,
#         -0.08951663225889206,
#         0.033011481165885925,
#         -0.024175196886062626,
#         0.012677795253694056,
#         -0.08529460430145264,
#         0.0581325963139534,
#         0.04147781804203987,
#         -0.007375063840299845,
#         -0.0022313734516501427,
#         0.11971630156040192,
#         -0.05555041134357453,
#         0.005013016518205404,
#         -0.01916147582232952,
#         0.03668661788105965,
#         -0.05545633286237717,
#         0.0003341976262163371,
#         -0.010818722657859324,
#         0.005691332742571831,
#         -0.04906757175922394,
#         -0.007015430834144354,
#         -0.050630513578653336,
#         -0.0241578072309494,
#         -0.016277534887194633,
#         -0.026822954416275024,
#         -0.04221806675195694,
#         0.09011264145374298,
#         0.07621268182992935,
#         0.04387499764561653,
#         0.054821424186229706,
#         -0.03724228963255882,
#         -0.0930868461728096,
#         -0.015031919814646244,
#         0.0368565209209919,
#         -0.0025658104568719864,
#         0.04161261394619942,
#         -0.008425289765000343,
#         0.09868496656417848,
#         -0.022898297756910324,
#         -0.07711955904960632,
#         0.01776672713458538,
#         -0.03767739981412888,
#         0.02095743641257286,
#         0.032428037375211716,
#         0.04856524243950844,
#         -0.031249811872839928,
#         -0.13164180517196655,
#         -0.020655939355492592,
#         0.015153275802731514,
#         -0.006340693216770887,
#         -0.008767565712332726,
#         -0.009397435002028942,
#         0.009787773713469504,
#         0.041317299008369446,
#         -0.039882149547338486,
#         0.04132092744112015,
#         -6.239371199899095e-33,
#         0.09030604362487792,
#         -0.019597619771957397,
#         -0.07312777638435364,
#         -0.06774260848760605,
#         0.1431196928024292,
#         -0.006071122828871012,
#         0.03939996659755707,
#         0.09695515781641006,
#         0.12122341990470886,
#         -0.027103496715426445,
#         -0.08621066063642502,
#         0.05720656737685203,
#         0.036240771412849426,
#         -0.02422691136598587,
#         0.025306764990091324,
#         -0.02330799773335457,
#         0.005037873983383179,
#         -0.011867067776620388,
#         0.06631629914045334,
#         -0.021945279091596603,
#         0.016652096062898636,
#         -0.013437376357614994,
#         -0.03346792235970497,
#         -0.01851595565676689,
#         0.06574659049510956,
#         0.040067438036203384,
#         0.04417439177632332,
#         -0.02270742878317833,
#         -0.08657028526067734,
#         0.0309357475489378,
#         0.007728328928351402,
#         0.002989762229844928,
#         0.04702051728963852,
#         0.04002166911959648,
#         -0.038550276309251785,
#         0.0731533020734787,
#         0.04808609187602997,
#         -0.0511464923620224,
#         -0.08670983463525772,
#         0.01240558736026287,
#         0.012394682504236698,
#         -0.05392572283744812,
#         -0.04636622220277786,
#         0.029114633798599243,
#         0.002238031243905425,
#         0.04192465543746948,
#         0.0941239967942238,
#         -0.002029727678745985,
#         -0.0879201591014862,
#         0.004154583439230919,
#         -0.023570388555526733,
#         -0.02279006503522396,
#         0.023539522662758827,
#         0.07409045100212097,
#         -0.00981923472136259,
#         -0.07853405177593231,
#         0.03448239713907242,
#         -0.04259354993700981,
#         -0.00677671330049634,
#         0.06570547074079514,
#         0.013376509770751,
#         0.0019650221802294254,
#         -0.013626192696392536,
#         -0.032285891473293304,
#         -0.1087486520409584,
#         0.03548063337802887,
#         -0.0034529161639511585,
#         -0.02002362720668316,
#         -0.06338908523321152,
#         -0.007318712770938873,
#         -0.08453166484832764,
#         -0.17355674505233765,
#         -0.03856898099184036,
#         -0.035702385008335114,
#         0.03771583363413811,
#         -0.08557005971670151,
#         -0.04998854920268059,
#         0.041887637227773666,
#         -0.022433869540691376,
#         -0.025617266073822975,
#         0.05081858113408089,
#         0.015459495596587658,
#         -0.044772788882255554,
#         0.04060928151011467,
#         0.08254355937242508,
#         0.040910590440034866,
#         0.046798866242170334,
#         0.01131373830139637,
#         0.038693588227033615,
#         0.10124564170837402,
#         -0.01799876242876053,
#         0.012860601767897606,
#         -0.01961355283856392,
#         0.00804373063147068,
#         -0.03749282285571098,
#         -6.310852285196233e-08,
#         0.01966421864926815,
#         0.001488646841607988,
#         0.00704563595354557,
#         0.016727948561310768,
#         -0.02554583176970482,
#         0.020508797839283943,
#         -0.05315835773944855,
#         0.14030040800571442,
#         0.012269172817468643,
#         0.07994375377893448,
#         -0.0805133804678917,
#         0.04025447368621826,
#         0.012616211548447607,
#         -0.003913882188498974,
#         -0.04848608374595642,
#         0.05119294300675392,
#         0.04882495477795601,
#         -0.026584433391690258,
#         -0.009727535769343376,
#         0.005404792260378599,
#         -0.01695561781525612,
#         -0.07429920881986618,
#         0.0514269545674324,
#         0.019028425216674805,
#         -0.02539684809744358,
#         0.01630118489265442,
#         0.01191028580069542,
#         -0.10106861591339111,
#         -0.02782126702368259,
#         0.02822505682706833,
#         0.018697701394557953,
#         0.07401137053966522,
#         -0.02311001531779766,
#         0.01735842041671276,
#         -0.044730547815561295,
#         0.01677030138671398,
#         0.04597078636288643,
#         0.011683781631290913,
#         0.04110177233815193,
#         -0.0143040856346488,
#         -0.023531559854745865,
#         0.10376526415348052,
#         0.04167528823018074,
#         -0.010763215832412245,
#         0.0925472229719162,
#         0.051253899931907654,
#         0.06456877291202545,
#         -0.048310812562704086,
#         0.04658428952097893,
#         -0.011347157880663872,
#         0.01547935139387846,
#         -0.016750909388065338,
#         -0.07239867746829987,
#         0.06846407055854797,
#         0.03453923016786575,
#         0.033468905836343765,
#         -0.001114875078201294,
#         -0.012952017597854136,
#         0.030214877799153328,
#         0.027395926415920258,
#         0.029301121830940247,
#         -0.0008670770330354571,
#         0.014750508591532707,
#         0.012138078920543194
#     ]
# }

# %% [markdown]
# ## Passo 3 - Criando o índex para o JSON do Filme
#
# Vamos criar o índex, sem segredo, pra gente fazer as queries depois.

# %%
import time

def create_index():
    indexes = redis.execute_command("FT._LIST")
    if "movie_idx" not in indexes:
        index_def = IndexDefinition(prefix=["moviebot:movie:"], index_type=IndexType.JSON)
        schema = (TextField("$.crew", as_name="crew"),
                  TextField("$.overview", as_name="overview"),
                  TagField("$.genre", as_name="genre"),
                  TagField("$.names", as_name="names"),
                  VectorField("$.overview_embedding", VSS_INDEX_TYPE,
                              {"TYPE": VSS_DATA_TYPE, "DIM": VSS_DIMENSION, "DISTANCE_METRIC": VSS_DISTANCE},
                              as_name="embedding"))
        redis.ft('movie_idx').create_index(schema, definition=index_def)
        print("The index has been created")
    else:
        print("The index exists")

# Cria o index aqui mesmo
create_index()
# Out:
# The index exists

# %% [markdown]
# E vamos testar o index por aqui mesmo também, fazendo uma Full Text Search bem preguiçosa

# %%
# Testa aqui mesmo
time.sleep(2)

# Executar a busca, direto aqui mesmo
# Redis é binary safe, então esse abaixo, com ñ, precisa funfar de boa
search_result = redis.execute_command("FT.SEARCH", "movie_idx", "@crew:'Zoe Saldaña'")
print(search_result)
# Out:
# [26, 'moviebot:movie:68', ['$', '{"names":"Avatar","date_x":"12/17/2009 ","score":"76.0","genre":"Action,\xa0Adventure,\xa0Fantasy,\xa0Science Fiction","overview":"In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.","crew":"Sam Worthington, Jake Sully, Zoe Saldaña, Neytiri, Sigourney Weaver, Dr. Grace Augustine, Stephen Lang, Colonel Miles Quaritch, Michelle Rodriguez, Trudy Chacon, Giovanni Ribisi, Parker Selfridge, Joel David Moore, Norm Spellman, CCH Pounder, Mo\'at, Wes Studi, Eytukan","orig_title":"Avatar","status":" Released","orig_lang":" English","budget_x":"237000000.0","revenue":"2923706026.0","country":"AU","overview_embedding":[-0.024951674044132233,0.021150358021259308,-0.009504531510174274,-0.06110683083534241,-0.06520567834377289,0.010032949037849905,-0.028909243643283844,-0.0449451245367527,0.039477039128541946,-0.0166932325810194,0.04766632989048958,-0.1117062196135521,0.015615132637321947,0.07239790260791779,-0.029082804918289185,0.06363720446825027,0.02963985502719879,0.004188708961009979,0.028133509680628777,0.00952219869941473,-0.012855024076998234,0.05610447376966477,-0.08506670594215393,0.02739242836833,-0.015866784378886223,0.02249297685921192,0.034782007336616516,-0.014056912623345852,-0.1019299104809761,-0.0084675382822752,-0.02092454768717289,0.13021984696388245,-0.034518808126449585,0.010045379400253296,-0.003183554857969284,0.07126455754041672,-0.07072548568248749,-0.1355929970741272,-0.05545487999916077,0.0017839479260146618,-0.04593759402632713,-0.03015136532485485,0.012892668135464191,-0.0866713747382164,0.0187138207256794,-0.09543898701667786,0.017367856577038765,-0.08805457502603531,0.0808868408203125,0.014043740928173063,-0.10582616180181505,-0.02036501280963421,-0.029957091435790065,0.041534874588251114,0.02723921462893486,-0.09438011795282364,-0.019570356234908104,-0.06659731268882751,0.013758699409663675,-0.11120838671922684,0.001878781709820032,-0.005194388795644045,0.09242861717939375,-0.02349572815001011,0.005001432728022337,-0.009014718234539032,-0.029635144397616383,-0.03745553269982338,-0.025860348716378212,-0.08006900548934937,-0.05967993289232254,-0.027103377506136898,-0.06315289437770844,-0.02318250760436058,-0.052980050444602966,0.04884492978453636,0.0006266781711019576,0.05225599929690361,-0.009968961589038372,-0.038159146904945374,0.08170410245656967,-0.049374084919691086,-0.05148503556847572,0.013071481138467789,0.04206220060586929,0.02337421104311943,0.039217911660671234,0.03505343198776245,0.0019030922558158636,0.083452507853508,-0.09371571242809296,-0.048607636243104935,0.07099249958992004,0.004899379797279835,0.01977633312344551,-0.011141618713736534,-0.07839108258485794,0.009112566709518433,-0.016290483996272087,-0.02534048818051815,0.06211182102560997,-0.02998112328350544,-0.029043370857834816,-0.04164057597517967,0.08494261652231216,-0.020129699259996418,0.1508408784866333,-0.05810729041695595,0.018342366442084312,0.020489247515797615,-0.03538811579346657,-0.02041646838188171,-0.009936514310538769,0.05659380555152893,0.004053593147546053,0.10386350005865096,-0.004743070807307959,0.02642283216118813,0.02361166477203369,0.04050400108098984,0.0596436932682991,-0.09754907339811324,0.01094579230993986,0.0043275849893689156,0.0339333601295948,-0.03060441836714745,0.0005296436720527709,7.238076343145496e-33,0.07786120474338531,-0.004200817085802555,0.03704296052455902,0.03637765347957611,0.04452066123485565,0.017684562131762505,-0.04890376701951027,0.08055225014686584,-0.1088155210018158,-0.03411427140235901,-0.18079979717731476,-0.011559049598872662,-0.008402572013437748,0.0776429995894432,-0.008430274203419685,-0.022064264863729477,-0.04522697627544403,0.0027468691114336252,0.05568578839302063,-0.025574764236807823,-0.036197222769260406,-0.04059038311243057,-0.15648967027664185,-0.02044631727039814,-0.03462616726756096,-0.018496498465538025,-0.06383435 ...
